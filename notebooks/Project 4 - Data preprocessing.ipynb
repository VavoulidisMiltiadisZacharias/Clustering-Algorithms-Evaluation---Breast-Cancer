# %% [markdown]
# # <div align="center"><u>Project 4 - Data preprocessing</u>

# %%
##############################################################################################################################

# %% [markdown]
# ###  Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import random
import time

from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ### Suppress warnings

# %%
# Suppress all warnings
import warnings

warnings.filterwarnings("ignore")

# %% [markdown]
# ### Start time

# %%
# Start time
start_time = time.time()

# %% [markdown]
# ### Load the dataset and store it within a pandas DataFrame

# %%
# Load the dataset and store it withina  panda dataframe to handle it easier
df = pd.read_csv(r"C:\Users\user\Desktop\VAVOULIDIS MILTIADIS - ZACHARIAS\Projects\Project 4\dataset.csv")

# Print the dataset
df
# Out:
#       id     V1     V2      V3      V4       V5       V6       V7       V8  \
# 0      1  17.99  10.38  122.80  1001.0  0.11840  0.27760  0.30010  0.14710
# 1      2  20.57  17.77  132.90  1326.0  0.08474  0.07864  0.08690  0.07017
# 2      3  19.69  21.25  130.00  1203.0  0.10960  0.15990  0.19740  0.12790
# 3      4  11.42  20.38   77.58   386.1  0.14250  0.28390  0.24140  0.10520
# 4      5  20.29  14.34  135.10  1297.0  0.10030  0.13280  0.19800  0.10430
# ..   ...    ...    ...     ...     ...      ...      ...      ...      ...
# 564  565  21.56  22.39  142.00  1479.0  0.11100  0.11590  0.24390  0.13890
# 565  566  20.13  28.25  131.20  1261.0  0.09780  0.10340  0.14400  0.09791
# 566  567  16.60  28.08  108.30   858.1  0.08455  0.10230  0.09251  0.05302
# 567  568  20.60  29.33  140.10  1265.0  0.11780  0.27700  0.35140  0.15200
# 568  569   7.76  24.54   47.92   181.0  0.05263  0.04362  0.00000  0.00000
#
# ...

# %%
# Count the occurrences of each unique value in the 'Class' column
benign_count = df["Class"].eq(1).sum()
malignant_count = df["Class"].eq(2).sum()

print("The number of beign cancer occurrences is:", benign_count)
print("The number of malignant cancer occurrences is:", malignant_count)

x = ["Benign", "Malignant"]
y = [benign_count, malignant_count]
colors = ["Orange", "Blue"]

# Create a bar plot
plt.bar(x, y, color=colors)

# Add title and labels and title
plt.title("Samples of each cancer type", fontsize = 14)
plt.xlabel("Cancer type", fontsize = 12)
plt.ylabel("Samples", fontsize = 12)

# Display the count above each bar
for i, v in enumerate(y):
    plt.text(i, v + 1, str(v), ha="center", fontsize=12)

# Display the plot
plt.show()
# Out:
# The number of beign cancer occurrences is: 357
# The number of malignant cancer occurrences is: 212

# %% [markdown]
# ### Drop the 'id' column

# %%
# Drop the 'id' column
df = df.drop(columns=["id"])

# Check result
df.head()
# Out:
#       V1     V2      V3      V4       V5       V6      V7       V8      V9  \
# 0  17.99  10.38  122.80  1001.0  0.11840  0.27760  0.3001  0.14710  0.2419
# 1  20.57  17.77  132.90  1326.0  0.08474  0.07864  0.0869  0.07017  0.1812
# 2  19.69  21.25  130.00  1203.0  0.10960  0.15990  0.1974  0.12790  0.2069
# 3  11.42  20.38   77.58   386.1  0.14250  0.28390  0.2414  0.10520  0.2597
# 4  20.29  14.34  135.10  1297.0  0.10030  0.13280  0.1980  0.10430  0.1809
#
#        V10  ...    V22     V23     V24     V25     V26     V27     V28  \
# 0  0.07871  ...  17.33  184.60  2019.0  0.1622  0.6656  0.7119  0.2654
# 1  0.05667  ...  23.41  158.80  1956.0  0.1238  0.1866  0.2416  0.1860
# 2  0.05999  ...  25.53  152.50  1709.0  0.1444  0.4245  0.4504  0.2430
# 3  0.09744  ...  26.50   98.87   567.7  0.2098  0.8663  0.6869  0.2575
# 4  0.05883  ...  16.67  152.20  1575.0  0.1374  0.2050  0.4000  0.1625
#
#       V29      V30  Class
# 0  0.4601  0.11890      2
# 1  0.2750  0.08902      2
# ...

# %% [markdown]
# ### Transform outliers

# %%
# Function that transforms outliers given a dataframe
def cap_outliers_iqr(df, threshold=1.5):
    df_capped = df.copy()

    for col in df.columns:
        # Skip non-numeric columns AND the label column
        if col == "Class":
            continue

        if pd.api.types.is_numeric_dtype(df_capped[col]):
            Q1 = df_capped[col].quantile(0.25)
            Q3 = df_capped[col].quantile(0.75)
            IQR = Q3 - Q1

            lower_bound = Q1 - threshold * IQR
            upper_bound = Q3 + threshold * IQR

            df_capped[col] = np.where(df_capped[col] < lower_bound, lower_bound, df_capped[col])
            df_capped[col] = np.where(df_capped[col] > upper_bound, upper_bound, df_capped[col])

        else:
            print(f"Warning: Column '{col}' is not numeric. Skipping.")

    return df_capped

# %%
# Transform outliers
df_capped = cap_outliers_iqr(df)
df_capped
# Out:
#         V1     V2      V3      V4        V5       V6       V7       V8  \
# 0    17.99  10.38  122.80  1001.0  0.118400  0.22862  0.28241  0.14710
# 1    20.57  17.77  132.90  1326.0  0.084740  0.07864  0.08690  0.07017
# 2    19.69  21.25  130.00  1203.0  0.109600  0.15990  0.19740  0.12790
# 3    11.42  20.38   77.58   386.1  0.133695  0.22862  0.24140  0.10520
# 4    20.29  14.34  135.10  1297.0  0.100300  0.13280  0.19800  0.10430
# ..     ...    ...     ...     ...       ...      ...      ...      ...
# 564  21.56  22.39  142.00  1326.3  0.111000  0.11590  0.24390  0.13890
# 565  20.13  28.25  131.20  1261.0  0.097800  0.10340  0.14400  0.09791
# 566  16.60  28.08  108.30   858.1  0.084550  0.10230  0.09251  0.05302
# 567  20.60  29.33  140.10  1265.0  0.117800  0.22862  0.28241  0.15200
# 568   7.76  24.54   47.92   181.0  0.057975  0.04362  0.00000  0.00000
#
#          V9      V10  ...    V22     V23      V24      V25      V26     V27  \
# ...

# %% [markdown]
# ### Check if "Transform Outliers" worked: Count how many elements are different between dataframes. If 0 nothing happened

# %%
# Compare element-wise and count differences
num_differences = (df != df_capped).sum().sum()

# Print results
if num_differences > 0:
    print(f"The tranformation of outliers worked. The amount of outliers that has been transformed is: {num_differences}")
else:
    print("No values transformed during outliers transformation phase")
# Out:
# The tranformation of outliers worked. The amount of outliers that has been transformed is: 608

# %% [markdown]
# ### Scale the dataset

# %%
# Separate features and label
X = df_capped.drop(columns=["Class"])
y = df_capped["Class"]

# Initialize scaler
scaler = StandardScaler()

# Fit + transform features
X_scaled = scaler.fit_transform(X)

# (optional) convert back to DataFrame for readability
X_scaled = pd.DataFrame(X_scaled, columns=X.columns)

#print(X_scaled.head())

# %% [markdown]
# ### Export the dataset to .csv file

# %%
# Export scaled dataset to .csv file
df_scaled = X_scaled.copy()
df_scaled["Class"] = y.values

# Export full dataset
file_path = r"C:\Users\user\Desktop\VAVOULIDIS MILTIADIS - ZACHARIAS\Projects\Project 4\final_dataset.csv"

df_scaled.to_csv(file_path, index=False)

print(f"CSV file saved at: {file_path}")
# Out:
# CSV file saved at: C:\Users\user\Desktop\VAVOULIDIS MILTIADIS - ZACHARIAS\Projects\Project 4\final_dataset.csv
